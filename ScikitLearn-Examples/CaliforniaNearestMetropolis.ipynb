# %%
import sklearn
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
import matplotlib.pylab as plt

# %%
california_data = fetch_california_housing(as_frame=True)
data = california_data.frame

# %%
# Step 2: Define the coordinates of the major cities
cities = {
    "San Diego": (32.7157, -117.1611),
    "San Francisco": (37.7749, -122.4194),
    "Los Angeles": (34.0522, -118.2437)
}

# %%
#define haversine formula to calculate distances
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great-circle distance between two points
    on the Earth's surface using the Haversine formula.
    Inputs are in degrees, output is in kilometers.
    """
    R = 6371.0  # Earth radius in kilometers
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

# %%
# Step 4: Add a function to calculate the minimum distance to the nearest city
def calculate_min_distance(row):
    lat, lon = row['Latitude'], row['Longitude']
    distances = [haversine(lat, lon, lat_city, lon_city) for lat_city, lon_city in cities.values()]
    return min(distances)

# %%
# Step 5: Apply the function to the dataset
data['min_distance_to_city'] = data.apply(calculate_min_distance, axis=1)

# %%
# Step 6: Save the enhanced dataset as a CSV file
data.to_csv('california_housing_with_distances.csv', index=False)

# %%
# Step 7: Print a preview of the dataset
#print(data.head(20))

# Print rows 20 to 40 (row indices 20 to 39)
print(data.iloc[2000:2040])
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 2000  2.5045      15.0  4.103933   1.165730       924.0  2.595506     36.74
# 2001  1.2375      35.0  4.459916   1.067511      2050.0  4.324895     36.75
# 2002  1.2813      31.0  3.627907   0.979328      1515.0  3.914729     36.75
# 2003  1.0513      35.0  2.951557   1.024221      1228.0  4.249135     36.74
# 2004  2.1094      52.0  2.059524   1.035714       401.0  4.773810     36.74
# 2005  0.7990      25.0  3.645435   1.150743      1343.0  2.851380     36.74
# 2006  1.3527      41.0  3.711409   1.042506      1391.0  3.111857     36.75
# 2007  1.1230      33.0  3.736407   1.104019      3530.0  4.172577     36.75
# 2008  1.8967      52.0  5.000000   1.049180       406.0  3.327869     36.74
# 2009  1.6435      25.0  5.070727   1.037328      1642.0  3.225933     36.72
# 2010  2.6176      17.0  5.361345   1.016807       927.0  3.894958     36.72
# 2011  2.4137      21.0  5.386076   1.132911      1347.0  4.262658     36.73
# 2012  4.3500      28.0  4.615385   0.769231        46.0  3.538462     36.72
# 2013  2.4167      43.0  4.733333   1.080000       233.0  3.106667     36.71
# 2014  1.2500      19.0  4.671196   1.062500      1369.0  3.720109     36.72
# 2015  2.0043      29.0  4.923323   0.929712      1007.0  3.217252     36.71
# 2016  1.5625      25.0  5.606557   1.207650       789.0  4.311475     36.71
# 2017  1.0481      19.0  4.181818   1.053292      1171.0  3.670846     36.72
# 2018  1.0472      15.0  5.088000   1.112000      1383.0  3.688000     36.72
# 2019  1.3922      23.0  5.076246   1.064516      1210.0  3.548387     36.70
# 2020  1.3304      28.0  5.645390   1.078014       962.0  3.411348     36.70
# 2021  1.2404      52.0  4.757576   0.863636       178.0  2.696970     36.70
# 2022  2.1458      22.0  3.078261   1.052174       530.0  4.608696     36.72
# 2023  1.3047      41.0  5.638989   1.162455       927.0  3.346570     36.72
# 2024  1.3587      35.0  5.187990   1.028721      1233.0  3.219321     36.71
# 2025  2.1905      17.0  4.797386   1.021242      5034.0  4.112745     36.71
# 2026  1.5611      29.0  4.462916   1.127877      1530.0  3.913043     36.71
# 2027  2.8750      24.0  5.344828   1.142241      1035.0  4.461207     36.72
# 2028  1.4577      38.0  3.981183   0.948925      1543.0  4.147849     36.71
# 2029  2.3269      34.0  4.494624   0.974910      1056.0  3.784946     36.73
# 2030  2.1304      25.0  5.448560   1.155007      2863.0  3.927298     36.72
# 2031  1.3343      22.0  3.685585   0.975028      4179.0  4.743473     36.72
# 2032  1.8723      46.0  5.044944   1.056180       854.0  3.198502     36.73
# 2033  1.4419      39.0  4.554252   1.064516      1449.0  4.249267     36.73
# 2034  1.6325      39.0  4.272388   1.005597      1685.0  3.143657     36.73
# 2035  2.0536      42.0  4.735632   1.042146       946.0  3.624521     36.73
# 2036  4.7463       6.0  6.094937   0.958861       965.0  3.053797     36.75
# 2037  2.7813      19.0  5.310476   1.169524      1365.0  2.600000     36.74
# 2038  1.5449      17.0  4.531599   1.111524      1563.0  2.905204     36.74
# 2039  4.0027      13.0  5.785185   1.009877      1347.0  3.325926     36.75
#
#       Longitude  MedHouseVal  min_distance_to_city
# 2000    -119.78        0.903            260.386041
# 2001    -119.78        0.500            259.882750
# 2002    -119.78        0.564            259.882750
# 2003    -119.79        0.396            259.592535
# 2004    -119.79        0.750            259.592535
# 2005    -119.80        0.518            258.799621
# 2006    -119.80        0.612            258.293448
# 2007    -119.79        0.467            259.087807
# 2008    -119.82        0.438            257.215592
# 2009    -119.82        0.526            258.245113
# 2010    -119.82        0.541            258.245113
# 2011    -119.83        0.621            256.938840
# 2012    -119.83        0.675            257.456965
# 2013    -119.83        0.739            257.978841
# 2014    -119.79        0.530            260.613286
# 2015    -119.80        0.535            260.340720
# 2016    -119.81        0.528            259.552797
# 2017    -119.80        0.485            259.823279
# 2018    -119.80        0.578            259.823279
# 2019    -119.79        0.495            261.648949
# 2020    -119.80        0.513            260.861872
# 2021    -119.81        0.525            260.075425
# 2022    -119.78        0.344            261.403900
# 2023    -119.79        0.441            260.613286
# 2024    -119.78        0.453            261.918425
# 2025    -119.74        0.618            265.081120
# 2026    -119.76        0.444            263.498573
# 2027    -119.76        0.606            262.986933
# 2028    -119.75        0.498            264.289550
# 2029    -119.74        0.508            264.067246
# 2030    -119.74        0.585            264.572333
# 2031    -119.75        0.608            263.779340
# 2032    -119.76        0.526            262.479004
# 2033    -119.76        0.455            262.479004
# 2034    -119.75        0.521            263.272836
# 2035    -119.74        0.500            264.067246
# 2036    -119.69        0.931            267.062657
# 2037    -119.67        1.203            269.152189
# 2038    -119.69        0.625            267.553372
# 2039    -119.69        0.931            267.062657

# %%
# Define target column (y) and feature columns (X)
target_column = "MedHouseVal"  # This is the target column
X = data.drop(columns=[target_column])  # Drop the target column to get features
y = data[target_column]  # Extract the target column

# %%
#Define the pipeline
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", KNeighborsRegressor())
])

# %%
#use GridSearchCV
mod = GridSearchCV(estimator=pipe,
    param_grid={'model__n_neighbors':[1,2,3,4,5]},
    cv = 3)

# %%
mod.fit(X, y)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('model', KNeighborsRegressor())]),
#              param_grid={'model__n_neighbors': [1, 2, 3, 4, 5]})

# %%
pd.DataFrame(mod.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.021873      0.007462         0.432273        0.060939
# 1       0.016436      0.000113         0.476765        0.057837
# 2       0.015427      0.000178         0.418895        0.061979
# 3       0.016254      0.000932         0.474143        0.077947
# 4       0.016259      0.000178         0.557001        0.064574
#
#    param_model__n_neighbors                     params  split0_test_score  \
# 0                         1  {'model__n_neighbors': 1}           0.168591
# 1                         2  {'model__n_neighbors': 2}           0.316701
# 2                         3  {'model__n_neighbors': 3}           0.376404
# 3                         4  {'model__n_neighbors': 4}           0.406501
# 4                         5  {'model__n_neighbors': 5}           0.420102
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.360018           0.295997         0.274869        0.079565
# 1           0.506395           0.376559         0.399885        0.079179
# 2           0.543473           0.406070         0.441982        0.072780
# 3           0.568286           0.425274         0.466687        0.072249
# 4           0.579128           0.434854         0.478028        0.071742
#
#    rank_test_score
# 0                5
# 1                4
# 2                3
# 3                2
# 4                1
