# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plab
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

# %%
#data
df = pd.read_csv("Data/ufo_sightings_scrubbed.csv")
# Out:
# /tmp/ipykernel_82986/3764850913.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data/ufo_sightings_scrubbed.csv")
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1  1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2  1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# ...

# %%
df_shapes = df[['shape']]
print(shapes.head(5))
# Out:
# 0    cylinder
# 1       light
# 2      circle
# 3      circle
# 4       light
# Name: shape, dtype: object

# %%
# Count the occurrences of each shape
shape_counts = df_shapes['shape'].value_counts()
# Sort counts for better visualization
shape_counts_sorted = shape_counts.sort_values(ascending=False)
# Filter out less common shapes if necessary (e.g., only show top 10)
top_shapes = shape_counts_sorted.head(10)

# %%
# Plot the data
plt.figure(figsize=(10, 6))
top_shapes.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 20 Most Reported UFO Shapes', fontsize=16)
plt.xlabel('Shape', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Group smaller categories into "Other"
threshold = 500  # Define a threshold for grouping
shape_counts_grouped = shape_counts.copy()
shape_counts_grouped['other'] = shape_counts_grouped[shape_counts_grouped < threshold].sum()
shape_counts_grouped = shape_counts_grouped[shape_counts_grouped >= threshold]

# Plot the pie chart
plt.figure(figsize=(8, 8))
shape_counts_grouped.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.tab20.colors)
plt.ylabel('')  # Remove default y-label
plt.title('Proportion of UFO Shapes', fontsize=16)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
shape_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.yscale('log')
plt.title('Frequency of UFO Shapes (Log Scale)', fontsize=16)
plt.xlabel('Shape', fontsize=14)
plt.ylabel('Count (log scale)', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
X_new = QuantileTransformer(n_quantiles=100)

# %%
def plot_output(scaler,X,y):
    pipe = Pipeline([
        ("scale", scaler),
        ("model", KNeighborsClassifier(n_neighbors=20, weights='distance'))
    ])

    pred = pipe.fit(X, y).predict(X)

    plab.figure(figsize=(9, 3))
    plab.subplot(131)
    plab.scatter(X[:, 0], X[:, 1], c=y)
    plab.title("Original Data")
    plab.subplot(132)
    X_tfm = scaler.transform(X)
    plab.scatter(X_tfm[:, 0], X_tfm[:, 1], c=y)
    plab.title("Transformed Data")
    plab.subplot(133)
    X_new = np.concatenate([
        np.random.uniform(0, X[:, 0].max(), (5000, 1)), 
        np.random.uniform(0, X[:, 1].max(), (5000, 1))
    ], axis=1)
    y_proba = pipe.predict_proba(X_new)
    plab.scatter(X_new[:, 0], X_new[:, 1], c=y_proba[:, 1], alpha=0.7)
    plab.title("Predicted Data")
