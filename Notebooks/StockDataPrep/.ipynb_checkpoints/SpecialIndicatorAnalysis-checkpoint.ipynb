# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_data = pd.read_csv("~/Downloads/special_indicator_stream1.csv")

# %%
file_data.head(10)
# Out:
#    95707.30444   50  50.1  50.2  50.3  50.4  50.5  50.6  50.7  50.8  50.9  \
# 0      95690.2   50    50    50    50    50    50    50    50    50    50
# 1      95686.8    0    50    50    50    50    50    50    50    50    50
# 2      95686.7   41     0    50    50    50    50    50    50    50    50
# 3      95683.2    0     0     0    50    50    50    50    50    50    50
# 4      95683.3    2    41     0    50    50    50    50    50    50    50
# 5      95691.5  100    84   100     0    50    50    50    50    50    50
# 6      95699.9  100   100    77   100    50    50    50    50    50    50
# 7      95700.0   75   100   100   100    50    50    50    50    50    50
# 8      95700.0   50    75   100   100     0    50    50    50    50    50
# 9      95699.9    0    50    81   100   100    50    50    50    50    50
#
#    50.10  50.11  50.12  50.13  50.14
# 0     50     50     50     50     50
# 1     50     50     50     50     50
# 2     50     50     50     50     50
# 3     50     50     50     50     50
# 4     50     50     50     50     50
# 5     50     50     50     50     50
# 6     50     50     50     50     50
# 7     50     50     50     50     50
# 8     50     50     50     50     50
# 9     50     50     50     50     50

# %%
# Select two columns by index (e.g., columns 0 and 1)
data = file_data.iloc[:, [0, 7]]

# Rename the columns
data.columns = ['close', 'indicator']

# %%
# calculate percent changes to make stationary
data.loc[:, 'close'] = data['close'].pct_change()

# clip the data
data.loc[:, 'close'] = data['close'].clip(-1000,1000)
# Out:
# /tmp/ipykernel_9488/2562940600.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data.loc[:, 'close'] = data['close'].pct_change()
# /tmp/ipykernel_9488/2562940600.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['close'] = data['close'].clip(-1000,1000)

# %%
plt.scatter(data['close'], data['indicator'], alpha=0.5)
